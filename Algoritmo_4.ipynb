# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def serie_geomerica(n):
    x= 0
    for i in range(1, n+1):
        x += 1/i   
    return x

serie_geomerica(1000000)
# Out:
# 14.392726722864989
